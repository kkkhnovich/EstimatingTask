# %%
# I made an assumption that all rooms are regular polygons, so we know the values of each angle. 
# Due to that, i could calculate coefficients of determination for ceiling's and floor's angles.

# %%
import estimating

# %%
# Here I'm creating an object of class ModelEvaluator, 
# which is responsible for displaying plots and coefficients of determination. 
# Class for drawing plots(called PlotDrawer) is a nested class of ModelEvaluator
model_evaluater = estimating.ModelEvaluator()

# %%
model_evaluater.display_statistics('deviation.json')
# Out:
# Coefficient of determination for floor's angles:0.9904269242317201
# Coefficient of determination for ceiling's angles:0.9871737074368045

# %%
# I drew those plots to show homoscedasticity.
model_evaluater.display_plots('deviation.json')
